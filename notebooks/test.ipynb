# %%
import pynndescent
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File d:\Program\anaconda3\envs\Fods\Lib\tempfile.py:257, in _mkstemp_inner(dir, pre, suf, flags, output_type)
#     256 try:
# --> 257     fd = _os.open(file, flags, 0o600)
#     258 except FileExistsError:
#
# PermissionError: [Errno 13] Permission denied: 'd:\\Program\\anaconda3\\envs\\Fods\\Lib\\site-packages\\pynndescent\\__pycache__\\tmpepcik_w6'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pynndescent
#
# File d:\Program\anaconda3\envs\Fods\Lib\site-packages\pynndescent\__init__.py:5
#       1 import sys
#       3 import numba
# ----> 5 from .pynndescent_ import NNDescent, PyNNDescentTransformer
#       7 if sys.version_info[:2] >= (3, 8):
# ...
